# %%
import random

#Lists
car_names = ["BMW" , "AUDI" , "MERCADES" , "KIA" , "RENAULT"]
car_colours = ["BLUE" , "RED" , "GREEN", "WHITE" , "PINK"]
bmw_models = ["M2" , "M3", "M4" , "M5" ,"M8"]
audi_models = ["A3" , "A4" , "A6" , "Q5" ,"TT"]
mercades_models = ["A-Class", "EQS" ,"C-Class" ,"EQC" , "G-Class"]
kia_models = ["Sportage" , "Picanto" , "Rio" , "Ceed" , "Sorento"]
renault_models = ["Clio" , "Captur" , "Zoe" , "Kadjar" , "Megane"]

#Number Generators
numgen = random.randint(0,4)
modelgen = random.randint(0,4)
colourgen = random.randint(0,4)

print("Basic Car Generator:")

#If Bool:
if numgen == 0:
 print(car_names[0])
elif numgen == 1:
 print(car_names[1])
elif numgen == 2:
  print(car_names[2])
elif numgen == 3:
  print(car_names[3])
elif numgen == 4:
  print(car_names[4])
else:
  print("Error")

print("Basic Car Colour Generator:")

if colourgen == 0:
  print(car_colours[0])
elif colourgen == 1:
  print(car_colours[1])
elif colourgen == 2:
  print(car_colours[2])
elif colourgen == 3:
  print(car_colours[3])
elif colourgen == 4:
  print(car_colours[4])
else:
  print("Error")

#BMW Code  
if numgen == 0:
 print("BMW Model Type:")

if modelgen == 0 and numgen == 0:
 print("I have randomly selected the " + bmw_models[0] + " model for you!")
elif modelgen == 1 and numgen == 0:
 print("I have randomly selected the " + bmw_models[1] + " model for you!")
elif modelgen == 2 and numgen == 0:
 print("I have randomly selected the " + bmw_models[2] + " model for you!")
elif modelgen == 3 and numgen == 0:
 print("I have randomly selected the " + bmw_models[3] + " model for you!")
elif modelgen == 4 and numgen == 0:
 print("I have randomly selected the " + bmw_models[4] + " model for you!")

 #BMW Model Costs
 # 0 = M2, 1 = M3 , 2 = M4 , 3 = M5 , 4 = M8
bmw_model_costs = ["£42,405","£78,175","£128,225","£107,520","£133,020"]

if numgen == 0:
   print("Cost Of Vehicle:")

if numgen == 0 and modelgen == 0:
  print(bmw_model_costs[0])
elif numgen == 0 and modelgen == 1:
  print(bmw_model_costs[1])
elif numgen == 0 and modelgen == 2:
  print(bmw_model_costs[2])
elif numgen == 0 and  modelgen == 3:
  print(bmw_model_costs[3])
elif numgen == 0 and  modelgen == 4:
  print(bmw_model_costs[4])


#Audi Code
if numgen == 1:
  print("Audi Model Type:")

if modelgen == 0 and numgen == 1:
  print("I have randomly selected the " + audi_models[0] + " model for you!")
elif modelgen == 1 and numgen == 1:
  print("I have randomly selected the " + audi_models[1] + " model for you!")
elif modelgen == 2 and numgen == 1:
  print("I have randomly selected the " + audi_models[2] + " model for you!")
elif modelgen == 3 and numgen == 1:
  print("I have randomly selected the " + audi_models[3] + " model for you!")
elif modelgen == 4 and numgen == 1:
  print("I have randomly selected the " + audi_models[4] + " model for you!")

#AUDI Model Costs
 # 0 = A3, 1 = A4 , 2 = A6 , 3 = Q5 , 4 = TT
audi_model_costs = ["£26,555","£33,020","£38,905","£47,125","£57,315"]

if numgen == 1:
   print("Cost Of Vehicle:")

if numgen == 1 and modelgen == 0:
  print(audi_model_costs[0])
elif numgen == 1 and modelgen == 1:
  print(audi_model_costs[1])
elif numgen == 1 and modelgen == 2:
  print(audi_model_costs[2])
elif numgen == 1 and modelgen == 3:
  print(audi_model_costs[3])
elif numgen == 1 and modelgen == 4:
  print(audi_model_costs[4])

#Mercades Code
if numgen == 2:
  print("Mercades Model Type:")

if modelgen == 0 and numgen == 2:
  print("I have randomly selected the " + mercades_models[0] + " model for you!")
elif modelgen == 1 and numgen == 2:
  print("I have randomly selected the " + mercades_models[1] + " model for you!")
elif modelgen == 2 and numgen == 2:
  print("I have randomly selected the " + mercades_models[2] + " model for you!")
elif modelgen == 3 and numgen == 2:
  print("I have randomly selected the " + mercades_models[3] + " model for you!")
elif modelgen == 4 and numgen == 2:
  print("I have randomly selected the " + mercades_models[4] + " model for you!")

#Mercades Model Costs
 # 0 = A-Class, 1 = EQS , 2 = C-Class , 3 = EQC , 4 = G-Class
mercades_model_costs = ["£29,660","£101,300","£38,780","£70,035","£120,275"]

if numgen == 2:
   print("Cost Of Vehicle:")

if numgen == 2 and modelgen == 0:
  print(mercades_model_costs[0])
elif numgen == 2 and modelgen == 1:
  print(mercades_model_costs[1])
elif numgen == 2 and modelgen == 2:
  print(mercades_model_costs[2])
elif numgen == 2 and modelgen == 3:
  print(mercades_model_costs[3])
elif numgen == 2 and modelgen == 4:
  print(mercades_model_costs[4])

#Kia Code
if numgen == 3:
  print("KIA Model Type:")

if modelgen == 0 and numgen == 3:
  print("I have randomly selected the " + kia_models[0] + " model for you!")
elif modelgen == 1 and numgen == 3:
  print("I have randomly selected the " + kia_models[1] + " model for you!")
elif modelgen == 2 and numgen == 3:
  print("I have randomly selected the " + kia_models[2] + " model for you!")
elif modelgen == 3 and numgen == 3:
  print("I have randomly selected the " + kia_models[3] + " model for you!")
elif modelgen == 4 and numgen == 3:
  print("I have randomly selected the " + kia_models[4] + " model for you!")

#Kia Model Costs
 # 0 = Sportage, 1 = Picanto , 2 = Rio , 3 = Ceed , 4 = Sorento
kia_model_costs = ["£25,965","£11,380","£10,733","£20,610","£39,315"]

if numgen == 3:
   print("Cost Of Vehicle:")

if numgen == 3 and modelgen == 0:
  print(kia_model_costs[0])
elif numgen == 3 and modelgen == 1:
  print(kia_model_costs[1])
elif numgen == 3 and modelgen == 2:
  print(kia_model_costs[2])
elif numgen == 3 and modelgen == 3:
  print(kia_model_costs[3])
elif numgen == 3 and modelgen == 4:
  print(kia_model_costs[4])

#Renault Code
if numgen == 4:
  print("Renault Model Type:")

if modelgen == 0 and numgen == 4:
  print("I have randomly selected the " + renault_models[0] + " model for you!")
elif modelgen == 1 and numgen == 4:
  print("I have randomly selected the " + renault_models[1] + " model for you!")
elif modelgen == 2 and numgen == 4:
  print("I have randomly selected the " + renault_models[2] + " model for you!")
elif modelgen == 3 and numgen == 4:
  print("I have randomly selected the " + renault_models[3] + " model for you!")
elif modelgen == 4 and numgen == 4:
  print("I have randomly selected the " + renault_models[4] + " model for you!")

#Renault Model Costs
 # 0 = Clio, 1 = Captur , 2 = Zoe , 3 = Kadjar , 4 = Megane
renault_model_costs = ["£17,850","£21,210","£29,240","£25,210","£35,240"]

if numgen == 4:
   print("Cost Of Vehicle:")

if numgen == 4 and modelgen == 0:
  print(renault_model_costs[0])
elif numgen == 4 and modelgen == 1:
  print(renault_model_costs[1])
elif numgen == 4 and modelgen == 2:
  print(renault_model_costs[2])
elif numgen == 4 and modelgen == 3:
  print(renault_model_costs[3])
elif numgen == 4 and modelgen == 4:
  print(renault_model_costs[4])
# Out:
# Basic Car Generator:
# KIA
# Basic Car Colour Generator:
# BLUE
# KIA Model Type:
# I have randomly selected the Ceed model for you!
# Cost Of Vehicle:
# £20,610
